# %%
# Lib import
import pandas as pd

# Data import
df_new_naz = pd.read_csv("../ScrapingScripts/RawOutput/RisultatiNazionali/REFERENDUM.csv")
df_new_com = pd.read_csv("../ScrapingScripts/RawOutput/RisultatiComunali/REFERENDUM.csv")

# %%
df_new_naz.drop_duplicates().shape[0] == df_new_naz.shape[0]
# Out:
# True

# %%
df_new_com.drop_duplicates().shape[0] == df_new_com.shape[0]
# Out:
# False

# %%
schema = pd.read_csv("../ScrapingScripts/RawOutput/RisultatiComunali/NAZIONALI.csv").columns

schema
# Out:
# Index(['TIPO_ELEZIONI', 'ANNO', 'LISTA', 'ABS_RANK', 'TIPO_METRICA', 'VOTI',
#        'LBL_TIPO_METRICA', 'FLG_NOT_VALID'],
#       dtype='object')

# %%
df_new[]
# Out:
#                     LISTA                 LBL_TIPO_METRICA  ABS_RANK  \
# 0       FRATELLI D'ITALIA                    Voti ottenuti         5
# 1                    LEGA                    Voti ottenuti         7
# 2     PARTITO DEMOCRATICO                    Voti ottenuti         8
# 3    AZIONE - ITALIA VIVA                    Voti ottenuti        10
# 4            FORZA ITALIA                    Voti ottenuti        11
# 5       FRATELLI D'ITALIA     Percentuale (su voti validi)         5
# 6       FRATELLI D'ITALIA  Percentuale (su aventi diritto)         5
# 7                    LEGA     Percentuale (su voti validi)         7
# 8     PARTITO DEMOCRATICO     Percentuale (su voti validi)         8
# 9                    LEGA  Percentuale (su aventi diritto)         7
# 10    PARTITO DEMOCRATICO  Percentuale (su aventi diritto)         8
# 11   AZIONE - ITALIA VIVA     Percentuale (su voti validi)        10
# 12           FORZA ITALIA     Percentuale (su voti validi)        11
# ...
